# %% [markdown]
# # [pyecharts 文档](https://github.com/chenjiandongx/pyecharts/blob/master/docs/zh-cn/documentation.md)

# %%
from pyecharts import Bar

attr = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
v1 = [2.0, 4.9, 7.0, 23.2, 25.6, 76.7, 135.6, 162.2, 32.6, 20.0, 6.4, 3.3]
v2 = [2.6, 5.9, 9.0, 26.4, 28.7, 70.7, 175.6, 182.2, 48.7, 18.8, 6.0, 2.3]
bar = Bar("Bar chart", "precipitation and evaporation one year")
bar.add("precipitation", attr, v1, mark_line=["average"], mark_point=["max", "min"])
bar.add("evaporation", attr, v2, mark_line=["average"], mark_point=["max", "min"])
bar
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="7e415ec27eca431fb697c9cd9dfeb52d" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('7e415ec27eca431fb697c9cd9dfeb52d'));
# var option =  {
#     "backgroundColor": "#fff",
#     "title": [
#         {
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtext": "precipitation and evaporation one year",
#             "text": "Bar chart",
#             "top": "auto",
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             },
#             "left": "auto"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "seriesId": 6844588,
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value",
#                         "valueDim": null
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "name": "precipitation",
#             "markPoint": {
#                 "data": [
#                     {
#                         "symbol": "pin",
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         },
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbolSize": 50
#                     },
#                     {
#                         "symbol": "pin",
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         },
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbolSize": 50
#                     }
#                 ]
#             },
#             "barCategoryGap": "20%",
#             "data": [
#                 2.0,
#                 4.9,
#                 7.0,
#                 23.2,
#                 25.6,
#                 76.7,
#                 135.6,
#                 162.2,
#                 32.6,
#                 20.0,
#                 6.4,
#                 3.3
#             ],
#             "type": "bar",
#             "stack": "",
#             "label": {
#                 "emphasis": {
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     },
#                     "show": true
#                 },
#                 "normal": {
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null,
#                     "show": false
#                 }
#             }
#         },
#         {
#             "seriesId": 6844588,
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value",
#                         "valueDim": null
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "name": "evaporation",
#             "markPoint": {
#                 "data": [
#                     {
#                         "symbol": "pin",
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         },
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbolSize": 50
#                     },
#                     {
#                         "symbol": "pin",
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         },
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbolSize": 50
#                     }
#                 ]
#             },
#             "barCategoryGap": "20%",
#             "data": [
#                 2.6,
#                 5.9,
#                 9.0,
#                 26.4,
#                 28.7,
#                 70.7,
#                 175.6,
#                 182.2,
#                 48.7,
#                 18.8,
#                 6.0,
#                 2.3
#             ],
#             "type": "bar",
#             "stack": "",
#             "label": {
#                 "emphasis": {
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     },
#                     "show": true
#                 },
#                 "normal": {
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null,
#                     "show": false
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "max": null,
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "margin": 8,
#                 "rotate": 0,
#                 "interval": "auto"
#             },
#             "boundaryGap": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameGap": 25,
#             "nameLocation": "middle",
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "name": "",
#             "min": null,
#             "position": null,
#             "type": "value"
#         }
#     ],
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "formatter": null,
#         "triggerOn": "mousemove|click",
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         }
#     },
#     "series_id": 6844588,
#     "xAxis": [
#         {
#             "show": true,
#             "max": null,
#             "axisLabel": {
#                 "interval": "auto",
#                 "margin": 8,
#                 "rotate": 0
#             },
#             "boundaryGap": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameGap": 25,
#             "data": [
#                 "Jan",
#                 "Feb",
#                 "Mar",
#                 "Apr",
#                 "May",
#                 "Jun",
#                 "Jul",
#                 "Aug",
#                 "Sep",
#                 "Oct",
#                 "Nov",
#                 "Dec"
#             ],
#             "nameLocation": "middle",
#             "axisTick": {
#                 "alignWithLabel": false

# %%
import random
from pyecharts import HeatMap

x_axis = ["12a", "1a", "2a", "3a", "4a", "5a", "6a", "7a", "8a", "9a", "10a", "11a",
          "12p", "1p", "2p", "3p", "4p", "5p", "6p", "7p", "8p", "9p", "10p", "11p"]
y_axis = ["Saturday", "Friday", "Thursday", "Wednesday", "Tuesday", "Monday", "Sunday"]
data = [[i, j, random.randint(0, 50)] for i in range(24) for j in range(7)]
heatmap = HeatMap()
heatmap.add("热力图直角坐标系", x_axis, y_axis, data, is_visualmap=True,
            visual_text_color="#000", visual_orient='horizontal')
heatmap
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="b75572cdcf4a4c6a955e5c1ffce53d77" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('b75572cdcf4a4c6a955e5c1ffce53d77'));
# var option =  {
#     "backgroundColor": "#fff",
#     "title": [
#         {
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtext": "",
#             "text": "",
#             "top": "auto",
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             },
#             "left": "auto"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "seriesId": 5049166,
#             "data": [
#                 [
#                     0,
#                     0,
#                     7
#                 ],
#                 [
#                     0,
#                     1,
#                     44
#                 ],
#                 [
#                     0,
#                     2,
#                     2
#                 ],
#                 [
#                     0,
#                     3,
#                     41
#                 ],
#                 [
#                     0,
#                     4,
#                     44
#                 ],
#                 [
#                     0,
#                     5,
#                     38
#                 ],
#                 [
#                     0,
#                     6,
#                     28
#                 ],
#                 [
#                     1,
#                     0,
#                     5
#                 ],
#                 [
#                     1,
#                     1,
#                     1
#                 ],
#                 [
#                     1,
#                     2,
#                     32
#                 ],
#                 [
#                     1,
#                     3,
#                     39
#                 ],
#                 [
#                     1,
#                     4,
#                     31
#                 ],
#                 [
#                     1,
#                     5,
#                     8
#                 ],
#                 [
#                     1,
#                     6,
#                     2
#                 ],
#                 [
#                     2,
#                     0,
#                     41
#                 ],
#                 [
#                     2,
#                     1,
#                     12
#                 ],
#                 [
#                     2,
#                     2,
#                     38
#                 ],
#                 [
#                     2,
#                     3,
#                     32
#                 ],
#                 [
#                     2,
#                     4,
#                     45
#                 ],
#                 [
#                     2,
#                     5,
#                     44
#                 ],
#                 [
#                     2,
#                     6,
#                     15
#                 ],
#                 [
#                     3,
#                     0,
#                     13
#                 ],
#                 [
#                     3,
#                     1,
#                     10
#                 ],
#                 [
#                     3,
#                     2,
#                     44
#                 ],
#                 [
#                     3,
#                     3,
#                     21
#                 ],
#                 [
#                     3,
#                     4,
#                     23
#                 ],
#                 [
#                     3,
#                     5,
#                     48
#                 ],
#                 [
#                     3,
#                     6,
#                     9
#                 ],
#                 [
#                     4,
#                     0,
#                     33
#                 ],
#                 [
#                     4,
#                     1,
#                     37
#                 ],
#                 [
#                     4,
#                     2,
#                     44
#                 ],
#                 [
#                     4,
#                     3,
#                     13
#                 ],
#                 [
#                     4,
#                     4,
#                     46
#                 ],
#                 [
#                     4,
#                     5,
#                     18
#                 ],
#                 [
#                     4,
#                     6,
#                     9
#                 ],
#                 [
#                     5,
#                     0,
#                     37
#                 ],
#                 [
#                     5,
#                     1,
#                     38
#                 ],
#                 [
#                     5,
#                     2,
#                     3
#                 ],
#                 [
#                     5,
#                     3,
#                     2
#                 ],
#                 [
#                     5,
#                     4,
#                     2
#                 ],
#                 [
#                     5,
#                     5,
#                     49
#                 ],
#                 [
#                     5,
#                     6,
#                     45
#                 ],
#                 [
#                     6,
#                     0,
#                     45
#                 ],
#                 [
#                     6,
#                     1,
#                     27
#                 ],
#                 [
#                     6,
#                     2,
#                     39
#                 ],
#                 [
#                     6,
#                     3,
#                     2
#                 ],
#                 [
#                     6,
#                     4,
#                     4
#                 ],
#                 [
#                     6,
#                     5,
#                     31
#                 ],
#                 [
#                     6,
#                     6,
#                     14
#                 ],
#                 [
#                     7,
#                     0,
#                     31
#                 ],
#                 [
#                     7,
#                     1,
#                     2
#                 ],
#                 [
#                     7,
#                     2,
#                     42
#                 ],
#                 [
#                     7,
#                     3,
#                     11
#                 ],
#                 [
#                     7,
#                     4,
#                     43
#                 ],
#                 [
#                     7,
#                     5,
#                     37
#                 ],
#                 [
#                     7,
#                     6,
#                     30
#                 ],
#                 [
#                     8,
#                     0,
#                     9
#                 ],
#                 [
#                     8,
#                     1,
#                     34
#                 ],
#                 [
#                     8,
#                     2,
#                     30
#                 ],
#                 [
#                     8,
#                     3,
#                     10
#                 ],
#                 [
#                     8,
#                     4,
#                     21

# %%
import datetime
import random
from pyecharts import HeatMap

begin = datetime.date(2013, 1, 1)
end = datetime.date(2013, 12, 31)
data = [[str(begin + datetime.timedelta(days=i)),
        random.randint(1000, 25000)] for i in range((end - begin).days + 1)]
heatmap = HeatMap("日历热力图示例", "某人 2017 年微信步数情况", width=900)
heatmap.add('', data, is_calendar_heatmap=True,
            visual_text_color='#000', visual_range_text=['', ''],
            visual_range=[1000, 25000], calendar_cell_size=['auto', 20],
            is_visualmap=True, calendar_date_range='2013',
            visual_orient="horizontal", visual_pos="center",
            visual_top="60%", is_piecewise=True)
heatmap
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="cb92bc98f18342c19d0f84b91714614d" style="width:900px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('cb92bc98f18342c19d0f84b91714614d'));
# var option =  {
#     "series_id": 5826387,
#     "calendar": {
#         "range": "2013",
#         "cellSize": [
#             "auto",
#             20
#         ]
#     },
#     "backgroundColor": "#fff",
#     "title": [
#         {
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtext": "\u67d0\u4eba 2017 \u5e74\u5fae\u4fe1\u6b65\u6570\u60c5\u51b5",
#             "text": "\u65e5\u5386\u70ed\u529b\u56fe\u793a\u4f8b",
#             "top": "auto",
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             },
#             "left": "auto"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "seriesId": 5826387,
#             "name": "",
#             "type": "heatmap",
#             "data": [
#                 [
#                     "2013-01-01",
#                     4192
#                 ],
#                 [
#                     "2013-01-02",
#                     19116
#                 ],
#                 [
#                     "2013-01-03",
#                     13180
#                 ],
#                 [
#                     "2013-01-04",
#                     18918
#                 ],
#                 [
#                     "2013-01-05",
#                     12851
#                 ],
#                 [
#                     "2013-01-06",
#                     4269
#                 ],
#                 [
#                     "2013-01-07",
#                     11191
#                 ],
#                 [
#                     "2013-01-08",
#                     3742
#                 ],
#                 [
#                     "2013-01-09",
#                     12218
#                 ],
#                 [
#                     "2013-01-10",
#                     2286
#                 ],
#                 [
#                     "2013-01-11",
#                     10635
#                 ],
#                 [
#                     "2013-01-12",
#                     13613
#                 ],
#                 [
#                     "2013-01-13",
#                     3713
#                 ],
#                 [
#                     "2013-01-14",
#                     21204
#                 ],
#                 [
#                     "2013-01-15",
#                     15074
#                 ],
#                 [
#                     "2013-01-16",
#                     16008
#                 ],
#                 [
#                     "2013-01-17",
#                     1359
#                 ],
#                 [
#                     "2013-01-18",
#                     1616
#                 ],
#                 [
#                     "2013-01-19",
#                     24416
#                 ],
#                 [
#                     "2013-01-20",
#                     7126
#                 ],
#                 [
#                     "2013-01-21",
#                     15776
#                 ],
#                 [
#                     "2013-01-22",
#                     23021
#                 ],
#                 [
#                     "2013-01-23",
#                     20313
#                 ],
#                 [
#                     "2013-01-24",
#                     21213
#                 ],
#                 [
#                     "2013-01-25",
#                     22428
#                 ],
#                 [
#                     "2013-01-26",
#                     3922
#                 ],
#                 [
#                     "2013-01-27",
#                     24585
#                 ],
#                 [
#                     "2013-01-28",
#                     13640
#                 ],
#                 [
#                     "2013-01-29",
#                     10830
#                 ],
#                 [
#                     "2013-01-30",
#                     1036
#                 ],
#                 [
#                     "2013-01-31",
#                     12542
#                 ],
#                 [
#                     "2013-02-01",
#                     17907
#                 ],
#                 [
#                     "2013-02-02",
#                     20754
#                 ],
#                 [
#                     "2013-02-03",
#                     17075
#                 ],
#                 [
#                     "2013-02-04",
#                     20876
#                 ],
#                 [
#                     "2013-02-05",
#                     4694
#                 ],
#                 [
#                     "2013-02-06",
#                     9424
#                 ],
#                 [
#                     "2013-02-07",
#                     8612
#                 ],
#                 [
#                     "2013-02-08",
#                     23290
#                 ],
#                 [
#                     "2013-02-09",
#                     19394
#                 ],
#                 [
#                     "2013-02-10",
#                     13799
#                 ],
#                 [
#                     "2013-02-11",
#                     2871
#                 ],
#                 [
#                     "2013-02-12",
#                     19992
#                 ],
#                 [
#                     "2013-02-13",
#                     21815
#                 ],
#                 [
#                     "2013-02-14",
#                     7614
#                 ],
#                 [
#                     "2013-02-15",
#                     3841
#                 ],
#                 [
#                     "2013-02-16",
#                     20740
#                 ],
#                 [
#                     "2013-02-17",
#                     21064
#                 ],
#                 [
#                     "2013-02-18",
#                     3718
#                 ],
#                 [
#                     "2013-02-19",
#                     9837
#                 ],
#                 [
#                     "2013-02-20",
#                     19990
#                 ],
#                 [
#                     "2013-02-21",
#                     17295
#                 ],
#                 [
#                     "2013-02-22",
#                     16760
#                 ],
#                 [
#                     "2013-02-23",
#                     14116
#                 ],
#                 [
#                     "2013-02-24",
#                     18065
#                 ],
#                 [
#                     "2013-02-25",
#                     3606
#                 ],
#                 [
#                     "2013-02-26",
#                     15057
#                 ],
#                 [
#                     "2013-02-27",
#                     6492
#                 ],
#                 [
#                     "2013-02-28",
#                     11800
#                 ],
#                 [
#                     "2013-03-01",
#                     10434
#                 ],
#                 [
#                     "2013-03-02",
#                     4805
#                 ],
#                 [
#                     "2013-03-03",
#                     21382
#                 ],
#                 [
#                     "2013-03-04",
#                     2068
#                 ],
#                 [
#                     "2013-03-05",
#                     4834
#                 ],
